# %%
name="Swapna"
print(type(name))
help(str)
# Out:
# <class 'str'>
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
True + True + True - False
# Out:
# 3

# %% [markdown]
# Mutable DS
# 1. List
# 2. Dictionary
# 3. Set
#
# Immutable
# 1. Tuple
# 2. Number
# 3. String.

# %%
# %%writefile carmodule1.py

#to write in .py file  - %% writefile.py
#%%writefile carCons.py
# dir  - List object attribute.
class CarApp:
    '''Car Application'''
    
    def __init__(self,name):
        '''Initialising CarApp Class '''
        self.name = name # object Variable
        print("Constructor Method:",name)
        
    def info(self): # self - Class reference arguement #cname is local variable
        '''car Information Method'''
        print("It's Audi Car:")
            
if __name__ == '__main__':
    AudiCar = CarApp("class Audi car")
    #dir(AudiCar)
    #help(AudiCar)
    #print(AudiCar.__doc__)
# Out:
# Writing carmodule1.py

# %%
from carmodule1 import CarApp

class DeluxCar(CarApp):
        '''Delux Car Inherited from CarApp'''
        
        def feature(self):
                '''Delux car feature'''
                print("Delux Car features")
                
        def info(self):               #method over riding
                '''Delux Car Information Method'''
                super().info()
                print("It's Delux Audi Car",self.name)

AudiCar1 = DeluxCar("Audi Car Name")
AudiCar1.info()
# Out:
# Constructor Method: Audi Car Name
# It's Audi Car:
# It's Delux Audi Car Audi Car Name

# %%
import re

#dir(re)
#help(re)
#help(re.match)
pattern_object = re.compile('[a-z]+',re.IGNORECASE)
print(pattern_object)
data = "welcome to regular expression pattern"
m= pattern_object.match(data) #match will match one string in the begining.
if m:
    print("Match Found",m.group())
    print("Match Start",m.start())
    print("Match End",m.end())
    print("Match span",m.span())
else:
    print("Match Not Found")
# Out:
# re.compile('[a-z]+', re.IGNORECASE)
# Match Found welcome
# Match Start 0
# Match End 7
# Match span (0, 7)

# %%
import re

#dir(re)
#help(re)
#help(re.match)
pattern_object = re.compile('[a-z]+',re.IGNORECASE)
print(pattern_object)
data = "3456welcome to regular expression pattern"
m= pattern_object.search(data) #match will match one string in the begining.
if m:
    print("Match Found",m.group())
    print("Match Start",m.start())
    print("Match End",m.end())
    print("Match span",m.span())
else:
    print("Match Not Found")
# Out:
# re.compile('[a-z]+', re.IGNORECASE)
# Match Found welcome
# Match Start 4
# Match End 11
# Match span (4, 11)

# %% [markdown]
# GIT:
# revert,reset and checkout. - to undo mistakes.
#
# 1. Repository. It can be created by GUI/from cmd using 3rd party tool.
# 2. Commit - Changes to be saved in Repo.
# 3. Branch.
# 4. Merge - merging the different branches.
# 5. pull - download changes from remote repo
# 6. push - upload local changes to the repo
# 7. clone - copy of repo
# 8.

# %%
m1 = pattern_object.findall(data)
print(m1)

m2 = re.findall('[a-z]+',data,re.IGNORECASE)
print(m2)
# Out:
# ['welcome', 'to', 'regular', 'expression', 'pattern']
# ['welcome', 'to', 'regular', 'expression', 'pattern']

# %%
raw_data = '''name is swapna and email swapna.m@gmail.com
Mobile is 9535190862 and address is bangalore and swapna.maddali@gmail.com
Account Number is 1234567890 and IFSC Code is HDFC1234 and PAN Number is ANACD1234F 
another mobile Number is 9848012340 and address is PUNE. another mobile Number is 9848012340 and address is PUNE. 
10.10.10.10 ip address 192.245.200.100'''

with open('mypersonal.txt','w') as file:
    file.write(raw_data) #write data to file
    
with open('mypersonal.txt','r') as file:
    data = file.read() # read data from file
    print(data)
# Out:
# name is swapna and email swapna.m@gmail.com
# Mobile is 9535190862 and address is bangalore and swapna.maddali@gmail.com
# Account Number is 1234567890 and IFSC Code is HDFC1234 and PAN Number is ANACD1234F
# another mobile Number is 9848012340 and address is PUNE. another mobile Number is 9848012340 and address is PUNE.
# 10.10.10.10 ip address 192.245.200.100

# %%
ifsc_code = re.findall(r'[A-Z]{4}\d{4}',raw_data)
print(ifsc_code)
ifsc_code_bound = re.findall(r'\b[A-Z]{4}\d{4}\b',raw_data) 
print(ifsc_code_bound)
pan_data = re.findall(r'[A-Z]{5}\d{4}[A-Z]',raw_data) 
print(pan_data)
email_data = re.findall(r'\b[A_Za-z0-9._%+-]+@[A_Za-z0-9.-]+\.[A-Z|a-z]{2,}\b',data)
print(email_data)
email_data1 = re.findall(r'\b[\w._]+@[\w]+\.[\w]{2,}\b',data)
print(email_data1)
ip_address = re.findall(r'\d{0,3}\.\d{0,3}\.\d{0,3}',data)
print(ip_address)
# Out:
# ['HDFC1234', 'NACD1234']
# ['HDFC1234']
# ['ANACD1234F']
# ['swapna.m@gmail.com', 'swapna.maddali@gmail.com']
# ['swapna.m@gmail.com', 'swapna.maddali@gmail.com']
# ['10.10.10', '192.245.200']

# %%
mobile_data = re.findall(r'\d{10}',raw_data)
print(mobile_data)
# Out:
# ['9535190862', '1234567890', '9848012340', '9848012340']

# %%
print("W to Python Testing")
# Out:
# W to Python Testing

# %%
import pandas as pd
mobile_series = pd.Series(mobile_data,index=)
print(mobile_series)
# Out:
# Series([], dtype: object)

# %%
#pip install --proxy http://gateway.schneider.zscaler.net/ pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.1.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.1.2-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
mobile_series = pd.Series(mobile_data,name='MobileNumber')
print(mobile_series)
print(mobile_data)

mobile_dict = {}
mobile_dict['Swapna'] = mobile_data[0]
mobile_dict['pankaj'] = mobile_data[1]
mobile_dict['Bhavi '] = mobile_data[2]
mobile_dict['Urshi'] = mobile_data[3]
print(mobile_dict)
print(mobile_dict.keys())
print(mobile_dict.values())

mobile_series1 = pd.Series(mobile_dict)
print(mobile_series1)
# Out:
# 0    9535190862
# 1    1234567890
# 2    9848012340
# 3    9848012340
# Name: MobileNumber, dtype: object
# ['9535190862', '1234567890', '9848012340', '9848012340']
# {'Swapna': '9535190862', 'pankaj': '1234567890', 'Bhavi ': '9848012340', 'Urshi': '9848012340'}
# dict_keys(['Swapna', 'pankaj', 'Bhavi ', 'Urshi'])
# dict_values(['9535190862', '1234567890', '9848012340', '9848012340'])
# Swapna    9535190862
# pankaj    1234567890
# Bhavi     9848012340
# Urshi     9848012340
# dtype: object

# %%
mobile_dataframe = pd.DataFrame(mobile_dict.items(),columns=['Name','MobileNumber'])
print(mobile_dataframe)
print(mobile_dataframe['Name'])
print(mobile_dataframe['MobileNumber'])
print(mobile_dataframe.shape)
print(mobile_dataframe.ndim)
mobile_dataframe.to_csv('mobile.csv',index=False)#write data to csv
mobile_dataframe1 = pd.read_csv('mobile.csv')#read data from csv file
print(mobile_dataframe1)
# Out:
#      Name MobileNumber
# 0  Swapna   9535190862
# 1  pankaj   1234567890
# 2  Bhavi    9848012340
# 3   Urshi   9848012340
# 0    Swapna
# 1    pankaj
# 2    Bhavi
# 3     Urshi
# Name: Name, dtype: object
# 0    9535190862
# 1    1234567890
# 2    9848012340
# 3    9848012340
# Name: MobileNumber, dtype: object
# (4, 2)
# 2
#      Name  MobileNumber
# 0  Swapna    9535190862
# 1  pankaj    1234567890
# 2  Bhavi     9848012340
# 3   Urshi    9848012340

# %% [markdown]
# C:\automation\practice\Phyton_Automation>gh auth login
# ? Where do you use GitHub? GitHub.com
# ? What is your preferred protocol for Git operations on this host? SSH
# ? Generate a new SSH key to add to your GitHub account? Yes
# ? Enter a passphrase for your new SSH key (Optional):
# ? Title for your SSH key: (GitHub CLI)
#
# ? Title for your SSH key: GitHub CLI
# ? How would you like to authenticate GitHub CLI? Login with a web browser
#
# ! First copy your one-time code: CAB8-8F53
# Press Enter to open https://github.com/login/device in your browser...
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol ssh
# ✓ Configured git protocol
# ✓ Uploaded the SSH key to your GitHub account: C:\Users\SESA766337\.ssh\id_ed25519.pub
# ✓ Logged in as Swapnamaddali0
#
# C:\automation\practice\Phyton_Automation>gh repo create phyton_automation --public
# GraphQL: Name already exists on this account (createRepository)
#
# C:\automation\practice\Phyton_Automation>gh repo create phyton_automation_training --public
# ✓ Created repository Swapnamaddali0/phyton_automation_training on GitHub
#   https://github.com/Swapnamaddali0/phyton_automation_training
